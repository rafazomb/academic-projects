# %% [markdown]
# <a href="https://colab.research.google.com/github/rafazomb/academic-projects/blob/main/receitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
res = 1
favSal = 0
favSob = 0
favDri = 0
def favoritar():
  print('Deseja favoritar a receita?')
  print('[1] - Sim')
  print('[2] - Não')
  res = int(input('Opção: '))
  return res

def lasanha():
  print('---Lasanha Bolonhesa----')
  print('Tempo de preparo: 1hr e 30min')
  print('Porções: para 6 a 8 pessoas')
  print('------Ingredientes------')
  print('500g de massa de lasanha pré-cozida')
  print('500g de carne moída')
  print('1 cebola')
  print('2 dentes de alho')
  print('1 lata de molho de tomate')
  print('2 xícaras de queijo muçarela ralado')
  print('2 xícaras de queijo parmesão ralado')
  print('Sal e pimenta a gosto')
  print('----Modo de Preparo-----')
  print('- Pique a cebola e o alho e, em uma panela, refogue ambos com azeite. Coloque a')
  print('carne moída e tempere a mistura com sal e pimenta e cozinhe, introduza o molho de tomate')
  print('e deixe cozer por alguns minutos.')
  print('- Em uma fôrma retangular, alterne camadas de massa pré-cozida, carne com molho')
  print('e queijo, repetindo o processo até as coisas acabarem. Com o forno preaquecido a 180°C,')
  print('introduza a lasanha por meia hora ou até o queijo dourar. Retire do forno e sirva')
  print('------------------------')

def empada():
  print('----Empada de Frango----')
  print('Tempo de preparo: 1hr')
  print('Porções: 12 empadas')
  print('------Ingredientes------')
  print('260g de farinha de trigo')
  print('200g de manteiga em cubos')
  print('1 ovo')
  print('Água gelada')
  print('260 gramas de frango cozido e desfiado')
  print('1 cebola')
  print('2 alhos')
  print('95g de milho verde')
  print('Sal e pimenta a gosto')
  print('Óleo vegetal')
  print('----Modo de Preparo-----')
  print('- Em uma tigela, misture farinha de trigo e manteiga, misture até formar uma farofa e,')
  print('posteriormente adicione água gelada e ovo, e mexa tudo até formar uma massa')
  print('homogênea, embrulhe e deixe na geladeira por meia hora.')
  print('Pique a cebola e o alho, coloque-os em uma panela e refogue em óleo vegetal.')
  print('- Introduza o frango desfiado, o milho verde e tempere a mistura com sal e pimenta,cozinhe')
  print('por alguns minutos e deixe separado')
  print('- Pegue a massa e a abra com um rolo em uma superfície enfarinhada, corte a massa')
  print('em círculos e forre uma forminha de empada untadas com óleo vegetal, coloque o frango')
  print('dentro da massa e cubra com mais massa, apertando as bordas para selar.')
  print('- Coloque as empadas no forno por 30 meia hora ou até dourar, retire do forno,')
  print('espere esfriar e desenforme.')
  print('------------------------')

def strogonoff():
  print('--Strogonoff de Frango--')
  print('Tempo de preparo: 30min')
  print('Porções: para 4 a 6 pessoas')
  print('------Ingredientes------')
  print('500g de filé de frango em tiras finas')
  print('1 cebola')
  print('2 alhos')
  print('1 lata de creme de leite')
  print('Ketchup')
  print('Mostarda')
  print('Sal e pimenta a gosto')
  print('Óleo vegetal')
  print('----Modo de Preparo-----')
  print('- Em uma panela, aqueça óleo vegetal, pique a cebola e o alho e refogue-os até')
  print('ficarem dourados. Introduza o frango em tiras e cozinhe até dourar, feito isso, tempere com')
  print('sal e pimenta. Coloque 1 colher de sopa de ketchup e uma de mostarda, misture bem e')
  print('deixe cozinhar por alguns minutos. Adicione creme de leite e aqueça, sem deixar ferver.')
  print('- Sirva.')

def tortaPal():
  print('----Torta de Palmito----')
  print('Tempo de preparo: 1hr')
  print('Porções: para 6 a 8 pessoas')
  print('------Ingredientes------')
  print('260g de farinha de trigo')
  print('100g de manteiga em cubos')
  print('1 ovo')
  print('Água gelada')
  print('800g de palmito picado')
  print('1 cebola')
  print('2 alhos')
  print('Azeite')
  print('240ml de leite')
  print('Sal e pimenta a gosto')
  print('Óleo vegetal')
  print('----Modo de Preparo-----')
  print('- Em uma tigela, misture farinha de trigo e manteiga, misture até formar uma farofa e,')
  print('posteriormente adicione água gelada e ovo, e mexa tudo até formar uma massa')
  print('homogênea, embrulhe e deixe na geladeira por meia hora.')
  print('- Aqueça, em uma panela, o azeite. Pique a cebola e o alho e os deixe refogar até')
  print('dourar, adicione o palmito picado e refogue. Dissolva a farinha de trigo no leite e coloque a')
  print('mistura na panela, mexa até engrossar, depois, tempere com sal e pimenta a gosto e')
  print('desligue o fogo.')
  print('- Com o forno preaquecido a 180°C, retire a massa da geladeira e abra, forre o fundo')
  print('e as loterias de uma fôrma untada com óleo vegetal. Coloque o recheio de palmito na')
  print('massa, jogue o queijo parmesão ralado por cima e cubra com a massa, apertando as')
  print('bordas. Leve a torta ao forno por meia hora, tire e sirva.')
  print('------------------------')

def coxinha():
  print('---Coxinha de Frango----')
  print('Tempo de preparo: 1hr e 30min')
  print('Porções: 20 coxinhas')
  print('------Ingredientes------')
  print('260g de frango cozido e desfiado')
  print('960 ml de caldo de frango')
  print('1 cebola')
  print('3 alhos')
  print('480g de Farinha de trigo')
  print('2 ovos')
  print('200g de farinha de rosca')
  print('Sal a gosto')
  print('Óleo vegetal')
  print('----Modo de Preparo-----')
  print('- Em uma panela, aqueça a manteiga e refogue a cebola e o alho (ambos picados)')
  print('até dourarem. Adicione o frango e tempere com sal e misture, introduza caldo de frango e')
  print('deixe ferver. Coloque a farinha de trigo e mexa até a massa desgrudar do fundo da panela.')
  print('- Tire a massa da panela e deixe esfriar.')
  print(' -Unte as mãos com óleo, pegue porções da massa e modele em formato de')
  print('coxinhas, passe-as no ovo batido e na farinha de rosca (nessa ordem). Aqueça com óleo')
  print('vegetal em uma panela e use-o para fritar as coxinhas. Retire-as e coloque sobre papel')
  print('toalha para tirar o excesso de óleo. Sirva.')
  print('------------------------')

def mousse():
  print('----Mousse de Limão-----')
  print('Tempo de preparo: 4hrs e 30min')
  print('Porções: para 4 a 6 pessoas')
  print('------Ingredientes------')
  print('1 lata de leite condensado')
  print('1 lata de creme de leite')
  print('Suco de limão')
  print('Raspas de Limão (opcional)')
  print('----Modo de Preparo-----')
  print('- Misture leite condensado, creme de leite e suco de limão. Bata no liquidificador até')
  print('obter uma massa homogênea. Despeje a mistura em taças individuais ou quaisquer')
  print('recipientes. Leve a geladeira por pelo menos 4 horas ou até firmar. Caso queira, coloque as')
  print('raspas de limão por cima para decorar.')
  print('------------------------')

def tortaHol():
  print('----Torta Holandesa-----')
  print('Tempo de preparo: 5hrs')
  print('Porções: para 8 a 10 pessoas')
  print('------Ingredientes------')
  print('200g de maizena')
  print('100g de manteiga')
  print('200g de chocolate meio amargo')
  print('1 lata de creme de leite')
  print('1 lata de creme de leite fresco')
  print('1 lata de leite condensado')
  print('1 colher de sopa de essência de baunilha')
  print('Chantily')
  print('300ml de creme de leite')
  print('Raspas de chocolate (opcional)')
  print('----Modo de Preparo-----')
  print('- Triture o maizena até virar uma farofa fina. Derreta a manteiga e, em uma tigela,')
  print('misture com a farofa de maizena até formar uma massa. Forre uma fôrma de torta com a')
  print('massa.')
  print('- Em uma panela, derreta o chocolate em banho-maria. Retire do fogo e misture com')
  print('leite condensado, creme de leite e essência de baunilha. Despeje o creme de chocolate')
  print('sobre a massa na fôrma.')
  print('- Bata o creme de leite fresco até atingir ponto de chantilly e derrame sobre o creme')
  print('de chocolate. Leve a torta para a geladeira por 4 horas ou até firmar. Na hora de servir, caso')
  print('queira, decore com raspa de chocolate')
  print('------------------------')

def pave():
  print('---Pavê de Chocolate----')
  print('Tempo de preparo: 2hrs e 30min')
  print('Porções: para 6 a 8 pessoas')
  print('------Ingredientes------')
  print('1 pacote de biscoito champanhe')
  print('1 lata de leite condensado')
  print('2 latas de creme de leite')
  print('60g de chocolate em pó')
  print('240ml de leite')
  print('Raspas de chocolate (opcional)')
  print('----Modo de Preparo-----')
  print('- Em uma tigela, misture leite condensado, 1 lata de creme de leite e o chocolate. Em')
  print('uma fôrma, faça camadas alternadas de biscoito e da mistura até acabarem os ingredientes')
  print('e derrame por cima uma camada de creme de chocolate.')
  print('- Em outro recipiente, misture creme de leite e leite e despeje por cima do pavê. Leve')
  print('para a geladeira por 2 horas ou até firmar. Quando servir, caso queira, coloque raspas de')
  print('chocolate por cima.')
  print('------------------------')

def pudim():
  print('---------Pudim----------')
  print('Tempo de preparo: 7hrs')
  print('Porções: para 8 a 10 pessoas')
  print('------Ingredientes------')
  print('1 lata de leite condensado')
  print('395ml de leite')
  print('3 ovos')
  print('1 colher de sopa de essência de baunilha')
  print('200g de açúcar')
  print('----Modo de Preparo-----')
  print('- Misture leite condensado, leite, ovos e essência de baunilha e bata até ter uma')
  print('mistura homogênea. Em uma fôrma de pudim, derreta o açúcar em fogo baixo até formar')
  print('caramelo. Despeje a mistura do pudim na fôrma caramelizada.')
  print('- Preaqueça o forno a 180°C. Cubra a fôrma com papel-alumínio e leve ao forno em')
  print('banho maria por 1 hora ou até firmar. Retire do forno e deixe esfriar, leve à geladeira por 6')
  print('horas até gelar. Posteriormente, desenforme o pudim e sirva gelado.')
  print('------------------------')

def brigadeiro():
  print('-------Brigadeiro-------')
  print('Tempo de preparo: 30min')
  print('Porções: 20 brigadeiros')
  print('------Ingredientes------')
  print('1 lata de leite condensado')
  print('3 colheres de sopa de chocolate em pó')
  print('1 colher de sopa de manteiga')
  print('Granulado de chocolate')
  print('----Modo de Preparo-----')
  print('- Misture o leite condensado, chocolate em pó e manteiga no fogo baixo e mexa até')
  print('desgrudar do fundo da panela. Tire do fogo e deixe esfriar. Posteriormente, com as mãos')
  print('untadas de manteiga, faça bolinhas com a massa e passe-as no granulado de chocolate.')
  print('- Sirva.')
  print('------------------------')

def mojito():
  print('---------Mojito---------')
  print('Tempo de preparo: 10 min')
  print('Porções: 1 drink')
  print('------Ingredientes------')
  print('50ml de rum')
  print('8 folhas de hortelã')
  print('Meio limão')
  print('Água com gás')
  print('Gelo')
  print('2 colheres de chá de açúcar')
  print('----Modo de Preparo-----')
  print('- No copo, coloque açúcar, limão e folhas de hortelã. Com um socador, amasse os')
  print('ingredientes, adicione o rum e mexa. Coloque gelo até o fim do copo e coloque água com')
  print('gás, misture e decore com folha de hortelã. Sirva.')
  print('------------------------')

def cuba():
  print('-------Cuba Libre-------')
  print('Tempo de preparo: 5min')
  print('Porções: 1 drink')
  print('------Ingredientes------')
  print('50ml de rum branco')
  print('Suco de meio limão')
  print('Refrigerante de cola')
  print('Gelo')
  print('Fatia de limão')
  print('----Modo de Preparo-----')
  print('- Em um copo, coloque rum e suco de limão. Coloque gelo até a boca do copo e')
  print('adicione refrigerante de cola. Decore com uma fatia de limão e sirva.')
  print('------------------------')

def caipirinha():
  print('-------Caipirinha-------')
  print('Tempo de preparo: 5min')
  print('Porções: 1 drink')
  print('------Ingredientes------')
  print('50ml de cachaça')
  print('Meio limão')
  print('2 colheres de chá de açúcar')
  print('Gelo')
  print('----Modo de Preparo-----')
  print('- Em um copo, coloque limão e açúcar. Macere os ingredientes, adicione a cachaça e')
  print('misture. Coloque gelo até a boca do copo, mexa mais um pouco e sirva.')
  print('------------------------')

def pina():
  print('------Piña Colada-------')
  print('Tempo de preparo: 5min')
  print('Porções: 1 drink')
  print('------Ingredientes------')
  print('50ml de rum branco')
  print('100ml de suco de abacaxi')
  print('50ml de leite de coco')
  print('Gelo')
  print('Fatia de abacaxi')
  print('----Modo de Preparo-----')
  print('- Coloque rum, suco de abacaxi, leite de coco e gelo e bata até formar uma mistura')
  print('cremosa. Coloque no copo, decore com a fatia de abacaxi e sirva.')
  print('------------------------')

def martini():
  print('--------Martini---------')
  print('Tempo de preparo: 5min')
  print('Porções: 1 drink')
  print('------Ingredientes------')
  print('60ml de gin')
  print('15ml de vermute seco')
  print('Gelo')
  print('Casca de limão')
  print('----Modo de Preparo-----')
  print('Adicione gin, vermute seco e gelo numa coqueteleira e bata, Coe a mistura para um')
  print('corpo de martini, torça uma casca de limão em cima do drink e, posteriormente, use-a para')
  print('decorar. Sirva.')
  print('------------------------')

print('     APP DE RECEITAS')
while res != 0:
 print('Selecione a opção que deseja')
 print('--------Receitas--------')
 print('[1] - PRATOS SALGADOS')
 print('[2] - SOBREMESAS')
 print('[3] - DRINKS')
 print('------Pesquisa por------')
 print('[4] - TEMPO DE PREPARO')
 print('[5] - NÚMERO DE PORÇÕES')
 print('[6] - FAVORITAS')
 print('------------------------')
 print('[0] - ENCERRAR PROGRAMA')
 res = int(input('Opção: '))
 print('------------------------')
 if res == 1:
        print('Qual prato salgado você deseja fazer?')
        print('[1] - LASANHA BOLONHESA')
        print('[2] - EMPADÃO DE FRANGO')
        print('[3] - STROGONOFF')
        print('[4] - TORTA DE PALMITO')
        print('[5] - COXINHA DE FRANGO')
        res = int(input('Opção: '))
        if res == 1:
                lasanha()
                if favoritar() == 1:
                  favSal = 1
        elif res == 2:
                empada()
                if favoritar() == 1:
                  favSal = 2
        elif res == 3:
                strogonoff()
                if favoritar() == 1:
                  favSal = 3
        elif res == 4:
                tortaPal()
                if favoritar() == 1:
                  favSal = 4
        elif res == 5:
                coxinha()
                if favoritar() == 1:
                  favSal = 5
        else:
                print('receita não encontrada.')
 elif res == 2:
        print('Qual sobremesa você deseja fazer?')
        print('[1] - MOUSSE DE LIMÃO')
        print('[2] - TORTA HOLANDESA')
        print('[3] - PAVÊ DE CHOCOLATE')
        print('[4] - PUDIM')
        print('[5] - BRIGADEIRO')
        res = int(input('Opção: '))
        if res == 1:
                mousse()
                if favoritar() == 1:
                  favSob = 1
        elif res == 2:
                tortaHol()
                if favoritar() == 1:
                  favSob = 2
        elif res == 3:
                pave()
                if favoritar() == 1:
                  favSob = 3
        elif res == 4:
                pudim()
                if favoritar() == 1:
                  favSob = 4
        elif res == 5:
                brigadeiro()
                if favoritar() == 1:
                  favSob = 5
        else:
                print('receita não encontrada.')
 elif res == 3:
        print('Qual drink você gostaria de fazer?')
        print('[1] - MOJITO')
        print('[2] - CUBA LIVRE')
        print('[3] - CAIPIRINHA')
        print('[4] - PIÑA COLADA')
        print('[5] - MARTINNI ')
        res = int(input('Opção: '))
        if res == 1:
                mojito()
                if favoritar() == 1:
                  favDri = 1
        elif res == 2:
                cuba()
                if favoritar() == 1:
                  favDri = 2
        elif res == 3:
                caipirinha()
                if favoritar() == 1:
                  favDri = 3
        elif res == 4:
                pina()
                if favoritar() == 1:
                  favDri = 4
        elif res == 5:
                martini()
                if favoritar() == 1:
                  favDri = 5
        else:
                print('receita não encontrada.')
 elif res == 4:
        print('Quer procurar por qual tempo de preparo?')
        print('[1] - ATÉ 1 HORA')
        print('[2] - ENTRE 1 E 3 HORAS')
        print('[3] - MAIS DE 3 HORAS')
        res = int(input("Opção: "))
        if res == 1:
          print('-----Prato  Salgado-----')
          print('[1] - EMPADÃO DE FRANGO')
          print('[2] - STROGONOFF')
          print('[3] - TORTA DE PALMITO')
          print('-------Sobremesa--------')
          print('[4] - BRIGADEIRO')
          print('---------Drink----------')
          print('[5] - MOJITO')
          print('[6] - CUBA LIVRE')
          print('[7] - CAIPIRINHA')
          print('[8] - PIÑA COLADA')
          print('[9] - MARTINNI ')
          res = int(input('Opção: '))
          if res == 1:
                empada()
                if favoritar() == 1:
                  favSal = 2
          elif res == 2:
                strogonoff()
                if favoritar() == 1:
                  favSal = 3
          elif res == 3:
                tortaPal
                if favoritar() == 1:
                  favSal = 4
          elif res == 4:
                brigadeiro()
                if favoritar() == 1:
                  favSob = 5
          elif res == 5:
                mojito()
                if favoritar() == 1:
                  favDri = 1
          elif res == 6:
                cuba()
                if favoritar() == 1:
                  favDri = 2
          elif res == 7:
                caipirinha()
                if favoritar() == 1:
                  favDri = 3
          elif res == 8:
                pina()
                if favoritar() == 1:
                  favDri = 4
          elif res == 9:
                martini()
                if favoritar() == 1:
                  favDri = 5
        elif res == 2:
          print('-----Prato  Salgado-----')
          print('[1] - LASANHA BOLONHESA')
          print('[2] - COXINHA DE FRANGO')
          print('-------Sobremesa--------')
          print('[3] - PAVÊ DE CHOCOLATE')
          res = int(input('Opção: '))
          if res == 1:
                lasanha()
                if favoritar() == 1:
                  favSal = 1
          elif res == 2:
                coxinha()
                if favoritar() == 1:
                  favSal = 5
          elif res == 3:
                pave()
                if favoritar() == 1:
                  favSob = 3
        elif res == 3:
          print('-------Sobremesa--------')
          print('[1] - MOUSSE DE LIMÃO')
          print('[2] - TORTA HOLANDESA')
          print('[3] - PUDIM')
          if res == 1:
                mousse()
                if favoritar() == 1:
                  favSob = 1
          elif res == 2:
                tortaHol()
                if favoritar() == 1:
                  favSob = 2
          elif res == 3:
                pudim()
                if favoritar() == 1:
                  favSob = 4
 elif res == 5:
        print('Qual número porções?')
        print('[1] - PARA 1 A 3 PESSOAS')
        print('[2] - PARA 4 A 6 PESSOAS')
        print('[3] - PARA 7 A 10 PESSOAS')
        res = int(input("Opção:"))
        if res == 1:
          print('-----Prato  Salgado-----')
          print('[1] - EMPADÃO DE FRANGO')
          print('[2] - COXINHA DE FRANGO')
          print('-------Sobremesa--------')
          print('[3] - BRIGADEIRO')
          print('---------Drink----------')
          print('[4] - MOJITO')
          print('[5] - CUBA LIVRE')
          print('[6] - CAIPIRINHA')
          print('[7] - PIÑA COLADA')
          print('[8] - MARTINNI ')
          res = int(input('Opção: '))
          if res == 1:
                empada()
                if favoritar() == 1:
                  favSal = 2
          elif res == 2:
                coxinha()
                if favoritar() == 1:
                  favSal = 5
          elif res == 3:
                brigadeiro()
                if favoritar() == 1:
                  favSob = 5
          elif res == 4:
                mojito()
                if favoritar() == 1:
                  favDri = 1
          elif res == 5:
                cuba()
                if favoritar() == 1:
                  favDri = 2
          elif res == 6:
                caipirinha()
                if favoritar() == 1:
                  favDri = 3
          elif res == 7:
                pina()
                if favoritar() == 1:
                  favDri = 4
          elif res == 8:
                martini()
                if favoritar() == 1:
                  favDri = 5
        elif res == 2:
          print('-----Prato  Salgado-----')
          print('[1] - STROGONOFF')
          print('-------Sobremesa--------')
          print('[2] - MOUSSE DE LIMÃO')
          res = int(input("Opção: "))
          if res == 1:
                strogonoff()
                if favoritar() == 1:
                  favSal = 3
          elif res == 2:
                mousse()
                if favoritar() == 1:
                  favSob = 1
        elif res == 3:
          print('-----Prato  Salgado-----')
          print('[1] - LASANHA BOLONHESA')
          print('[2] - TORTA DE PALMITO')
          print('-------Sobremesa--------')
          print('[3] - TORTA HOLANDESA')
          print('[4] - PAVÊ DE CHOCOLATE')
          print('[5] - PUDIM')
          res = int(input('Opção: '))
          if res == 1:
                lasanha()
                if favoritar() == 1:
                  favSal = 1
          elif res == 2:
                tortaPal()
                if favoritar() == 1:
                  favSal = 4
          elif res == 3:
                tortaHol()
                if favoritar() == 1:
                  favSob = 2
          elif res == 4:
                pave()
                if favoritar() == 1:
                  favSob = 3
          elif res == 5:
                pudim()
                if favoritar() == 1:
                  favSob = 4
 elif res == 6:
        print('Receitas marcadas como favoritas:')
        if favSal == 0 and favSob == 0 and favDri == 0:
          print('Sem receitas marcadas como favorita.')
        else:
          if favSal > 0:
            print('-Prato Salgado Favorito-')
            print('[1] - ',end='')
            if favSal == 1:
              print('LASANHA BOLONHESA')
            elif favSal == 2:
              print('EMPADÃO DE FRANGO')
            elif favSal == 3:
              print('STROGONOFF')
            elif favSal == 4:
              print('TORTA DE PALMITO')
            elif favSal == 5:
              print('COXINHA DE FRANGO')
          if favSob > 0:
            print('---Sobremesa favorita---')
            print('[2] - ',end='')
            if favSob == 1:
              print('MOUSSE DE LIMÃO')
            elif favSob == 2:
              print('TORTA HOLANDESA')
            elif favSob == 3:
              print('PAVÊ DE CHOCOLATE')
            elif favSob == 4:
              print('PUDIM')
            elif favSob == 5:
              print('BRIGADEIRO')
          if favDri > 0:
            print('-----Drink Favorito-----')
            print('[3] - ',end='')
            if favDri == 1:
              print('MOJITO')
            elif favDri == 2:
              print('CUBA LIVRE')
            elif favDri == 3:
              print('CAIPIRINHA')
            elif favDri == 4:
              print('PIÑA COLADA')
            elif favDri == 5:
              print('MARTINNI')
          print('------Desfavoritar------')
          if favSal > 0:
            print('[4] - Prato Salgado')
          if favSob > 0:
            print('[5] - Sobremesa')
          if favDri > 0:
            print('[6] - Drink')
          res = int(input("Opção: "))
          if res == 1:
            if favSal == 1:
              lasanha()
            elif favSal == 2:
              empada()
            elif favSal == 3:
              strogonoff()
            elif favSal == 4:
              tortaPal()
            elif favSal == 5:
              coxinha()
          elif res == 2:
            if favSob == 1:
              mousse()
            elif favSob == 2:
              tortaHol()
            elif favSob == 3:
              pave()
            elif favSob == 4:
              pudim()
            elif favSob == 5:
              brigadeiro()
          elif res == 3:
            if favDri == 1:
              mojito()
            elif favDri == 2:
              cuba()
            elif favDri == 3:
              caipirinha()
            elif favDri == 4:
              pina()
            elif favDri == 5:
              martini()
          elif res == 4:
            favSal = 0
          elif res == 5:
            favSob = 0
          elif res == 6:
            favDri = 0
 elif res == 0:
        print('Programa encerrado.')
 print('------------------------')
# Out:
#      APP DE RECEITAS
# Selecione a opção que deseja
# --------Receitas--------
# [1] - PRATOS SALGADOS
# [2] - SOBREMESAS
# [3] - DRINKS
# ------Pesquisa por------
# [4] - TEMPO DE PREPARO
# [5] - NÚMERO DE PORÇÕES
# [6] - FAVORITAS
# ------------------------
# [0] - ENCERRAR PROGRAMA
# Opção: 4
# ------------------------
# Quer procurar por qual tempo de preparo?
# [1] - ATÉ 1 HORA
# [2] - ENTRE 1 E 3 HORAS
# [3] - MAIS DE 3 HORAS
# Opção: 1
# -----Prato  Salgado-----
# [1] - EMPADÃO DE FRANGO
# [2] - STROGONOFF
# [3] - TORTA DE PALMITO
# -------Sobremesa--------
# [4] - BRIGADEIRO
# ---------Drink----------
# [5] - MOJITO
# [6] - CUBA LIVRE
# [7] - CAIPIRINHA
# [8] - PIÑA COLADA
# [9] - MARTINNI
# Opção: 2
# --Strogonoff de Frango--
# Tempo de preparo: 30min
# Porções: para 4 a 6 pessoas
# ------Ingredientes------
# 500g de filé de frango em tiras finas
# 1 cebola
# 2 alhos
# 1 lata de creme de leite
# Ketchup
# Mostarda
# Sal e pimenta a gosto
# Óleo vegetal
# ...
